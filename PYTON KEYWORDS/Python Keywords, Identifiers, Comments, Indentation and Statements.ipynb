# %%
#Q1. Explain the significance of Python keywords 
# and provide examples of five keywords?
 
#ANSWER:
"""Python keywords are reserved words in Python that have special meaning and 
are used to define the structure and logic of the program. 
We cannot use keywords as variable names, function names, or class names.
Examples of Python keywords (any five):
if


else


for


while


def"""

# %%
#Q2. Describe the rules for defining identifiers in Python 
#and provide an example.

#ANSWER:
"""Identifiers are names used for variables, functions, classes, etc.
Rules for identifiers in Python:
1.Identifier must start with a letter (A-Z / a-z) or underscore _.
2.It cannot start with a number.
3.It can contain letters, digits, and underscore _.
4.No spaces are allowed.
5.Special symbols like @ # $ % are not allowed.
6.Keywords cannot be used as identifiers.
7.Identifiers are case-sensitive (age and Age are different)."""

#EXAMPLE:
student_name = "Rahul"
age2 = 20

# %%
#Q3. What are comments in Python, and why are they useful?
#Provide an example.
#ANSWER:
"""Comments are lines in a program that are not executed by
Python. They are used to explain code and make it easier to
understand.

Why comments are useful:

1.Improve readability of code.
2.Help in understanding the program.
3.Useful for debugging and maintenance.

Example:"""
# This is a comment
x = 10  # storing value in x

# %%
#Q4. Why is proper indentation important in Python?

#ANSWER:
"""Python uses indentation to define blocks of code.
 Indentation is very important because it shows which statements 
belong to loops, conditions, functions, etc.Without proper
indentation, Python cannot understand the structure of the code.

Example:"""
if True:
    print("Inside if block")
print("Outside block")

# %%
#Q5. What happens if indentation is incorrect in Python?

#ANSWER:
"""If indentation is incorrect, Python will give an error such as:

IndentationError

TabError (if spaces and tabs are mixed)

Example:"""
if True:
print("Hello")  # IndentationError

# %%
#Q6. Differentiate between expression 
#and statement in Python with examples.

#ANSWER:
"""Expression

An expression is a combination of values, variables, and operators that produces a result (value).

Examples of expressions:"""

10 + 5
x * 2
"a" + "b"

"""Statement

A statement is an instruction that performs an action, such as assignment, condition, loop, etc.

Examples of statements:"""

x = 10
if x > 5:
    print(x)
